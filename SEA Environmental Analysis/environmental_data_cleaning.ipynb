# %%
# Install the necessary packages and read the proper items
! pip install kaggle
! pip install pyspark
! apt-get install p7zip-full
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285388 sha256=cee7a2045525bf4c28a6a78e4a2ad86a4794dc1d7dd7abb8bb4c1fa456362865
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# Download the dataset
# !kaggle datasets download michaelbryantds/greenhouse-gas-emissions-dataset
#Unzip greenhouse-gas-emissions-dataset.zip
!7za x greenhouse-gas-emissions-dataset.zip
# Out:
# Downloading greenhouse-gas-emissions-dataset.zip to /content
# 100% 1.88G/1.88G [01:17<00:00, 30.4MB/s]
# 100% 1.88G/1.88G [01:17<00:00, 26.2MB/s]
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 2023032318 bytes (1930 MiB)
#
# Extracting archive: greenhouse-gas-emissions-dataset.zip
# --
# Path = greenhouse-gas-emissions-dataset.zip
# Type = zip
# Physical Size = 2023032318
#
# Everything is Ok
#
# Files: 54
# Size:       77422262561
# Compressed: 2023032318

# %%
# Import the libraries
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark import SparkContext, SparkConf
import pyspark as spark
#from pyspark.sql.functions import isnull, col, lit
#from pyspark.sql.functions import regexp_replace
from pyspark.sql.functions import *
import os

spark = SparkSession.builder.getOrCreate()
categories = ['agriculture', 'buildings', 'fluorinated_gases', 'fossil_fuel_operations', 'manufacturing', 'mineral_extraction', 'power', 'waste']

dataset = {'agriculture': [], 'buildings': [], 'fluorinated_gases': [], 'fossil_fuel_operations': [], 'manufacturing': [], 'mineral_extraction': [],
           'power': [], 'waste': []}
name_dataset = {'agriculture': [], 'buildings': [], 'fluorinated_gases': [], 'fossil_fuel_operations': [], 'manufacturing': [], 'mineral_extraction': [],
           'power': [], 'waste': []}

def show_schemas(df):
  """Shows all the schemas in the path."""

  df.printSchema()

def get_uniquness(df, column: str):
  """Show all of the unique values in a column."""

  try:
    return df.select(column).distinct()
  except:
    print('No Column Present')

# %%
# Create the dataset
for item in categories:
  print(f'=========================================================')
  print(f'{item} is processing')
  print(f'=========================================================')
  for files in os.listdir(item):
    print(f'{files} is processing...')
    path = f'{item}/{files}'
    df = spark.read.csv(path, header = True, inferSchema = True)
    data_tuple = (files, df)
    dataset[item].append(data_tuple)
print(dataset)
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# country_manure-management_emissions.csv is processing...
# country_cropland-fires_emissions.csv is processing...
# asset_cropland-fires_emissions.csv is processing...
# asset_enteric-fermentation_emissions.csv is processing...
# country_rice-cultivation_emissions.csv is processing...
# asset_synthetic-fertilizer-application-top500_emissions.csv is processing...
# country_synthetic-fertilizer-application_emissions.csv is processing...
# country_other-agricultural-soil-emissions_emissions.csv is processing...
# asset_enteric-fermentation_ownership.csv is processing...
# asset_manure-management_emissions.csv is processing...
# asset_rice-cultivation-top500_emissions.csv is processing...
# country_enteric-fermentation_emissions.csv is processing...
# =========================================================
# buildings is processing
# =========================================================
# country_residential-and-commercial-onsite-fuel-usage_emissions.csv is processing...
# country_other-onsite-fuel-usage_emissions.csv is processing...
# =========================================================
# fluorinated_gases is processing
# =========================================================
# country_fluorinated-gases_emissions.csv is processing...
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# country_other-fossil-fuel-operations_emissions.csv is processing...
# country_coal-mining_emissions.csv is processing...
# country_solid-fuel-transformation_emissions.csv is processing...
# asset_oil-and-gas-refining_ownership.csv is processing...
# asset_oil-and-gas-production-and-transport_ownership.csv is processing...
# asset_coal-mining_emissions.csv is processing...
# country_oil-and-gas-refining_emissions.csv is processing...
# country_oil-and-gas-production-and-transport_emissions.csv is processing...
# asset_oil-and-gas-production-and-transport_emissions.csv is processing...
# asset_oil-and-gas-refining_emissions.csv is processing...
# =========================================================
# manufacturing is processing
# =========================================================
# country_other-manufacturing_emissions.csv is processing...
# country_chemicals_emissions.csv is processing...
# country_pulp-and-paper_emissions.csv is processing...
# asset_cement_ownership.csv is processing...
# asset_cement_emissions.csv is processing...
# country_cement_emissions.csv is processing...
# country_aluminum_emissions.csv is processing...
# asset_steel_emissions.csv is processing...
# country_steel_emissions.csv is processing...
# asset_steel_ownership.csv is processing...
# asset_aluminum_emissions.csv is processing...
# =========================================================
# mineral_extraction is processing
# =========================================================
# asset_copper-mining_emissions.csv is processing...
# country_iron-mining_emissions.csv is processing...
# asset_bauxite-mining_emissions.csv is processing...
# country_bauxite-mining_emissions.csv is processing...
# country_sand-quarrying_emissions.csv is processing...
# country_rock-quarrying_emissions.csv is processing...
# country_copper-mining_emissions.csv is processing...
# asset_iron-mining_emissions.csv is processing...
# =========================================================
# power is processing
# =========================================================
# country_other-energy-use_emissions.csv is processing...
# asset_electricity-generation_ownership.csv is processing...
# country_electricity-generation_emissions.csv is processing...
# asset_electricity-generation_emissions.csv is processing...
# =========================================================
# waste is processing
# =========================================================
# country_incineration-and-open-burning-of-waste_emissions.csv is processing...
# country_biological-treatment-of-solid-waste-and-biogenic_emissions.csv is processing...
# asset_solid-waste-disposal_emissions.csv is processing...
# country_solid-waste-disposal_emissions.csv is processing...
# country_wastewater-treatment-and-discharge_emissions.csv is processing...
# asset_solid-waste-disposal_ownership.csv is processing...
# {'agriculture': [('country_manure-management_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp]), ('country_cropland-fires_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp]), ('asset_cropland-fires_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: int, activity: double, activity_units: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string]), ('asset_enteric-fermentation_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, lat_lon: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: string, activity: int, activity_units: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string]), ('country_rice-cultivation_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp]), ('asset_synthetic-fertilizer-application-top500_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: string, activity: double, activity_units: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string]), ('country_synthetic-fertilizer-application_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: string]), ('country_other-agricultural-soil-emissions_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp]), ('asset_enteric-fermentation_ownership.csv', DataFrame[asset_id: int, asset_name: string, owner_name: string, owner_classification: string, percentage_of_ownership: string, owner_direct_parent: string, owner_grouping: string, operator_name: string, percentage_of_operation: string, data_source: string, url: string, recency: timestamp, created_date: timestamp, original_inventory_sector: string]), ('asset_manure-management_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, lat_lon: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: string, activity: int, activity_units: string ...

# %%
# Print the Schemas for Dataset (Data tuple = (name, dataframe) )
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')
  for data_tuple in dataset[category]:
    print(data_tuple)
    names, df = data_tuple
    print(f'Schema for: {names}')
    show_schemas(df)
    print(f'=========================================================')
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# ('country_manure-management_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_manure-management_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_cropland-fires_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_cropland-fires_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_cropland-fires_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: int, activity: double, activity_units: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_cropland-fires_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: integer (nullable = true)
#  |-- activity: double (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('asset_enteric-fermentation_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, lat_lon: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: string, activity: int, activity_units: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_enteric-fermentation_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- lat_lon: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- activity: integer (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('country_rice-cultivation_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_rice-cultivation_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_synthetic-fertilizer-application-top500_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: string, activity: double, activity_units: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_synthetic-fertilizer-application-top500_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- activity: double (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('country_synthetic-fertilizer-application_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: string])
# Schema for: country_synthetic-fertilizer-application_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# ('country_other-agricultural-soil-emissions_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_other-agricultural-soil-emissions_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_enteric-fermentation_ownership.csv', DataFrame[asset_id: int, asset_name: string, owner_name: string, owner_classification: string, percentage_of_ownership: string, owner_direct_parent: string, owner_grouping: string, operator_name: string, percentage_of_operation: string, data_source: string, url: string, recency: timestamp, created_date: timestamp, original_inventory_sector: string])
# Schema for: asset_enteric-fermentation_ownership.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- owner_name: string (nullable = true)
#  |-- owner_classification: string (nullable = true)
#  |-- percentage_of_ownership: string (nullable = true)
#  |-- owner_direct_parent: string (nullable = true)
#  |-- owner_grouping: string (nullable = true)
#  |-- operator_name: string (nullable = true)
#  |-- percentage_of_operation: string (nullable = true)
#  |-- data_source: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- recency: timestamp (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#
# =========================================================
# ('asset_manure-management_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, lat_lon: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: string, activity: int, activity_units: string, created_date: timestamp, modified_date: timestamp, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_manure-management_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- lat_lon: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- activity: integer (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('asset_rice-cultivation-top500_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: string, capacity_units: string, capacity_factor: string, activity: int, activity_units: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_rice-cultivation-top500_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: string (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- activity: integer (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('country_enteric-fermentation_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_enteric-fermentation_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# ('country_residential-and-commercial-onsite-fuel-usage_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_residential-and-commercial-onsite-fuel-usage_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_other-onsite-fuel-usage_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_other-onsite-fuel-usage_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# ('country_fluorinated-gases_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_fluorinated-gases_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# ('country_other-fossil-fuel-operations_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_other-fossil-fuel-operations_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_coal-mining_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_coal-mining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_solid-fuel-transformation_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_solid-fuel-transformation_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_oil-and-gas-refining_ownership.csv', DataFrame[asset_id: int, asset_name: string, owner_name: string, owner_classification: string, percentage_of_ownership: string, owner_direct_parent: string, owner_grouping: string, operator_name: string, percentage_of_operation: string, data_source: string, url: string, recency: timestamp, created_date: timestamp, original_inventory_sector: string])
# Schema for: asset_oil-and-gas-refining_ownership.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- owner_name: string (nullable = true)
#  |-- owner_classification: string (nullable = true)
#  |-- percentage_of_ownership: string (nullable = true)
#  |-- owner_direct_parent: string (nullable = true)
#  |-- owner_grouping: string (nullable = true)
#  |-- operator_name: string (nullable = true)
#  |-- percentage_of_operation: string (nullable = true)
#  |-- data_source: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- recency: timestamp (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#
# =========================================================
# ('asset_oil-and-gas-production-and-transport_ownership.csv', DataFrame[asset_id: int, asset_name: string, owner_name: string, owner_classification: string, percentage_of_ownership: double, owner_direct_parent: string, owner_grouping: string, operator_name: string, percentage_of_operation: string, data_source: string, url: string, recency: timestamp, created_date: timestamp, original_inventory_sector: string])
# Schema for: asset_oil-and-gas-production-and-transport_ownership.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- owner_name: string (nullable = true)
#  |-- owner_classification: string (nullable = true)
#  |-- percentage_of_ownership: double (nullable = true)
#  |-- owner_direct_parent: string (nullable = true)
#  |-- owner_grouping: string (nullable = true)
#  |-- operator_name: string (nullable = true)
#  |-- percentage_of_operation: string (nullable = true)
#  |-- data_source: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- recency: timestamp (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#
# =========================================================
# ('asset_coal-mining_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, lat_lon: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: double, activity: double, activity_units: string, created_date: timestamp, modified_date: timestamp, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_coal-mining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- lat_lon: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- activity: double (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('country_oil-and-gas-refining_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_oil-and-gas-refining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_oil-and-gas-production-and-transport_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_oil-and-gas-production-and-transport_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_oil-and-gas-production-and-transport_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, created_date: timestamp, modified_date: timestamp, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_oil-and-gas-production-and-transport_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('asset_oil-and-gas-refining_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, emissions_factor: string, emissions_factor_units: string, capacity: int, capacity_units: string, capacity_factor: string, created_date: timestamp, modified_date: timestamp, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_oil-and-gas-refining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: string (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: integer (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# =========================================================
# manufacturing is processing
# =========================================================
# ('country_other-manufacturing_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_other-manufacturing_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_chemicals_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: int, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_chemicals_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_pulp-and-paper_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_pulp-and-paper_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_cement_ownership.csv', DataFrame[asset_id: int, asset_name: string, owner_name: string, owner_classification: string, percentage_of_ownership: double, owner_direct_parent: string, owner_grouping: string, operator_name: string, percentage_of_operation: string, data_source: string, url: string, recency: timestamp, created_date: timestamp, original_inventory_sector: string])
# Schema for: asset_cement_ownership.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- owner_name: string (nullable = true)
#  |-- owner_classification: string (nullable = true)
#  |-- percentage_of_ownership: double (nullable = true)
#  |-- owner_direct_parent: string (nullable = true)
#  |-- owner_grouping: string (nullable = true)
#  |-- operator_name: string (nullable = true)
#  |-- percentage_of_operation: string (nullable = true)
#  |-- data_source: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- recency: timestamp (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#
# =========================================================
# ('asset_cement_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: int, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: double, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_cement_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('country_cement_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: int, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_cement_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_aluminum_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: int, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: string])
# Schema for: country_aluminum_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# ('asset_steel_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: int, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: double, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_steel_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('country_steel_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: int, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_steel_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_steel_ownership.csv', DataFrame[asset_id: int, asset_name: string, owner_name: string, owner_classification: string, percentage_of_ownership: double, owner_direct_parent: string, owner_grouping: string, operator_name: string, percentage_of_operation: string, data_source: string, url: string, recency: timestamp, created_date: timestamp, original_inventory_sector: string])
# Schema for: asset_steel_ownership.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- owner_name: string (nullable = true)
#  |-- owner_classification: string (nullable = true)
#  |-- percentage_of_ownership: double (nullable = true)
#  |-- owner_direct_parent: string (nullable = true)
#  |-- owner_grouping: string (nullable = true)
#  |-- operator_name: string (nullable = true)
#  |-- percentage_of_operation: string (nullable = true)
#  |-- data_source: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- recency: timestamp (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#
# =========================================================
# ('asset_aluminum_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: int, emissions_factor: double, emissions_factor_units: string, capacity: int, capacity_units: string, capacity_factor: double, created_date: timestamp, modified_date: timestamp, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_aluminum_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: integer (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# =========================================================
# mineral_extraction is processing
# =========================================================
# ('asset_copper-mining_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, capacity: string, capacity_units: string, capacity_factor: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_copper-mining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- capacity: string (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('country_iron-mining_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: string])
# Schema for: country_iron-mining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# ('asset_bauxite-mining_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, capacity: string, capacity_units: string, capacity_factor: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_bauxite-mining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- capacity: string (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('country_bauxite-mining_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: string])
# Schema for: country_bauxite-mining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# ('country_sand-quarrying_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: int, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: string])
# Schema for: country_sand-quarrying_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# ('country_rock-quarrying_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: string])
# Schema for: country_rock-quarrying_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# ('country_copper-mining_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: string])
# Schema for: country_copper-mining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# ('asset_iron-mining_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, capacity: string, capacity_units: string, capacity_factor: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_iron-mining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- capacity: string (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# =========================================================
# power is processing
# =========================================================
# ('country_other-energy-use_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_other-energy-use_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_electricity-generation_ownership.csv', DataFrame[asset_id: int, asset_name: string, owner_name: string, owner_classification: string, percentage_of_ownership: double, owner_direct_parent: string, owner_grouping: string, operator_name: string, percentage_of_operation: string, data_source: string, url: string, recency: timestamp, created_date: timestamp, original_inventory_sector: string])
# Schema for: asset_electricity-generation_ownership.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- owner_name: string (nullable = true)
#  |-- owner_classification: string (nullable = true)
#  |-- percentage_of_ownership: double (nullable = true)
#  |-- owner_direct_parent: string (nullable = true)
#  |-- owner_grouping: string (nullable = true)
#  |-- operator_name: string (nullable = true)
#  |-- percentage_of_operation: string (nullable = true)
#  |-- data_source: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- recency: timestamp (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#
# =========================================================
# ('country_electricity-generation_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: bigint, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_electricity-generation_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: long (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_electricity-generation_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: int, emissions_factor: double, emissions_factor_units: string, capacity: int, capacity_units: string, capacity_factor: double, activity: int, activity_units: string, created_date: timestamp, modified_date: timestamp, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_electricity-generation_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: integer (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- activity: integer (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# =========================================================
# waste is processing
# =========================================================
# ('country_incineration-and-open-burning-of-waste_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_incineration-and-open-burning-of-waste_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_biological-treatment-of-solid-waste-and-biogenic_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_biological-treatment-of-solid-waste-and-biogenic_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_solid-waste-disposal_emissions.csv', DataFrame[asset_id: int, iso3_country: string, original_inventory_sector: string, start_time: timestamp, end_time: timestamp, temporal_granularity: string, gas: string, emissions_quantity: double, emissions_factor: double, emissions_factor_units: string, capacity: double, capacity_units: string, capacity_factor: string, activity: double, activity_units: string, created_date: timestamp, modified_date: string, asset_name: string, asset_type: string, st_astext: string])
# Schema for: asset_solid-waste-disposal_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- activity: double (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# ('country_solid-waste-disposal_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_solid-waste-disposal_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('country_wastewater-treatment-and-discharge_emissions.csv', DataFrame[iso3_country: string, start_time: timestamp, end_time: timestamp, original_inventory_sector: string, gas: string, emissions_quantity: double, emissions_quantity_units: string, temporal_granularity: string, created_date: timestamp, modified_date: timestamp])
# Schema for: country_wastewater-treatment-and-discharge_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# ('asset_solid-waste-disposal_ownership.csv', DataFrame[asset_id: int, asset_name: string, owner_name: string, owner_classification: string, percentage_of_ownership: string, owner_direct_parent: string, owner_grouping: string, operator_name: string, percentage_of_operation: string, data_source: string, url: string, recency: timestamp, created_date: timestamp, original_inventory_sector: string])
# Schema for: asset_solid-waste-disposal_ownership.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- owner_name: string (nullable = true)
#  |-- owner_classification: string (nullable = true)
#  |-- percentage_of_ownership: string (nullable = true)
#  |-- owner_direct_parent: string (nullable = true)
#  |-- owner_grouping: string (nullable = true)
#  |-- operator_name: string (nullable = true)
#  |-- percentage_of_operation: string (nullable = true)
#  |-- data_source: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- recency: timestamp (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#
# =========================================================

# %%
# Filter Country to South east asian countries

country_list = ['IDN', 'MYR', 'BRN', 'KHM', 'VNM', 'THA', 'MMR', 'SGP', 'PHL', 'TLS', 'LAO']
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')

  removal= []

  for data_tuple in dataset[category]:
    names, df = data_tuple
    try:
      filtered_dataset = df.filter(col('iso3_country').isin(country_list))
      new_tuple = (names, filtered_dataset)
      index = dataset[category].index(data_tuple)
      dataset[category][index] = new_tuple
    except:
      print(f'Error for the dataset: {names}...')
      removal.append(data_tuple)
      continue

  for tuples in removal:
    names, df = tuples
    print(f'removing: {names}')
    dataset[category].remove(tuples)
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# Error for the dataset: asset_enteric-fermentation_ownership.csv...
# removing: asset_enteric-fermentation_ownership.csv
# =========================================================
# buildings is processing
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# Error for the dataset: asset_oil-and-gas-refining_ownership.csv...
# Error for the dataset: asset_oil-and-gas-production-and-transport_ownership.csv...
# removing: asset_oil-and-gas-refining_ownership.csv
# removing: asset_oil-and-gas-production-and-transport_ownership.csv
# =========================================================
# manufacturing is processing
# =========================================================
# Error for the dataset: asset_cement_ownership.csv...
# Error for the dataset: asset_steel_ownership.csv...
# removing: asset_cement_ownership.csv
# removing: asset_steel_ownership.csv
# =========================================================
# mineral_extraction is processing
# =========================================================
# =========================================================
# power is processing
# =========================================================
# Error for the dataset: asset_electricity-generation_ownership.csv...
# removing: asset_electricity-generation_ownership.csv
# =========================================================
# waste is processing
# =========================================================
# Error for the dataset: asset_solid-waste-disposal_ownership.csv...
# removing: asset_solid-waste-disposal_ownership.csv

# %%
# Checking and removing values without any countries

for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')

  removal = []

  for data_tuple in dataset[category]:
    name, df = data_tuple

    try:
      country = get_uniquness(df, 'iso3_country')
      if country.count() == 0:
        print('Column is empty..., Removing')
        removal.append(data_tuple)
      else:
        country.show()
    except:
      print(f'Countries not shown for {name}')
      removal.append(data_tuple)

  for item in removal:
    names, df = item
    print(f'Removing {names}')
    dataset[category].remove(item)
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# |         SGP|
# +------------+
#
# Column is empty..., Removing
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         VNM|
# |         MMR|
# |         IDN|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# Column is empty..., Removing
# +------------+
# |iso3_country|
# +------------+
# |         VNM|
# |         KHM|
# |         MMR|
# |         IDN|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# Removing asset_enteric-fermentation_emissions.csv
# Removing asset_manure-management_emissions.csv
# =========================================================
# buildings is processing
# =========================================================
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# =========================================================
# fluorinated_gases is processing
# =========================================================
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         THA|
# |         VNM|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         THA|
# |         TLS|
# |         VNM|
# |         MMR|
# |         IDN|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         VNM|
# |         SGP|
# |         IDN|
# |         PHL|
# +------------+
#
# =========================================================
# manufacturing is processing
# =========================================================
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         THA|
# |         VNM|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         THA|
# |         VNM|
# |         SGP|
# |         IDN|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         IDN|
# +------------+
#
# =========================================================
# mineral_extraction is processing
# =========================================================
# +------------+
# |iso3_country|
# +------------+
# |         MMR|
# |         IDN|
# |         LAO|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         VNM|
# |         IDN|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         VNM|
# |         PHL|
# +------------+
#
# =========================================================
# power is processing
# =========================================================
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         THA|
# |         VNM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# =========================================================
# waste is processing
# =========================================================
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         MMR|
# |         KHM|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+
#
# +------------+
# |iso3_country|
# +------------+
# |         BRN|
# |         THA|
# |         TLS|
# |         VNM|
# |         SGP|
# |         KHM|
# |         MMR|
# |         IDN|
# |         LAO|
# |         PHL|
# +------------+

# %%
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')
  for data_tuple in dataset[category]:
    names, df = data_tuple
    print(f'Schema for: {names}')
    show_schemas(df)
    print(f'=========================================================')
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# Schema for: country_manure-management_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_cropland-fires_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: asset_cropland-fires_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: integer (nullable = true)
#  |-- activity: double (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: country_rice-cultivation_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: asset_synthetic-fertilizer-application-top500_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- activity: double (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: country_synthetic-fertilizer-application_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# Schema for: country_other-agricultural-soil-emissions_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: asset_rice-cultivation-top500_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: string (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- activity: integer (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: country_enteric-fermentation_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# Schema for: country_residential-and-commercial-onsite-fuel-usage_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_other-onsite-fuel-usage_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# Schema for: country_fluorinated-gases_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# Schema for: country_other-fossil-fuel-operations_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_coal-mining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_solid-fuel-transformation_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: asset_coal-mining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- lat_lon: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- activity: double (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: country_oil-and-gas-refining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_oil-and-gas-production-and-transport_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: asset_oil-and-gas-production-and-transport_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: asset_oil-and-gas-refining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: string (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: integer (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# =========================================================
# manufacturing is processing
# =========================================================
# Schema for: country_other-manufacturing_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_chemicals_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_pulp-and-paper_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: asset_cement_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: country_cement_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_aluminum_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# Schema for: asset_steel_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: country_steel_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: asset_aluminum_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: integer (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# =========================================================
# mineral_extraction is processing
# =========================================================
# Schema for: asset_copper-mining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- capacity: string (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: country_iron-mining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# Schema for: asset_bauxite-mining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- capacity: string (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: country_bauxite-mining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# Schema for: country_sand-quarrying_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# Schema for: country_rock-quarrying_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# Schema for: country_copper-mining_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#
# =========================================================
# Schema for: asset_iron-mining_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- capacity: string (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# =========================================================
# power is processing
# =========================================================
# Schema for: country_other-energy-use_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_electricity-generation_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: long (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: asset_electricity-generation_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: integer (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: double (nullable = true)
#  |-- activity: integer (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# =========================================================
# waste is processing
# =========================================================
# Schema for: country_incineration-and-open-burning-of-waste_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_biological-treatment-of-solid-waste-and-biogenic_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: asset_solid-waste-disposal_emissions.csv
# root
#  |-- asset_id: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_factor: double (nullable = true)
#  |-- emissions_factor_units: string (nullable = true)
#  |-- capacity: double (nullable = true)
#  |-- capacity_units: string (nullable = true)
#  |-- capacity_factor: string (nullable = true)
#  |-- activity: double (nullable = true)
#  |-- activity_units: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: string (nullable = true)
#  |-- asset_name: string (nullable = true)
#  |-- asset_type: string (nullable = true)
#  |-- st_astext: string (nullable = true)
#
# =========================================================
# Schema for: country_solid-waste-disposal_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================
# Schema for: country_wastewater-treatment-and-discharge_emissions.csv
# root
#  |-- iso3_country: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- original_inventory_sector: string (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- emissions_quantity_units: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- created_date: timestamp (nullable = true)
#  |-- modified_date: timestamp (nullable = true)
#
# =========================================================

# %%
# Modify the columns.

columns = ['start_time', 'end_time', 'gas', 'emissions_quantity', 'iso3_country', 'temporal_granularity']
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')

  removal = []
  for data_tuple in dataset[category]:
    names, df = data_tuple
    try:
      filtered_dataset = df.select(*columns)
      index = dataset[category].index(data_tuple)
      dataset[category][index] = (names, filtered_dataset)
    except:
      print(f'Error for the dataset: {names}')
      removal.append(data_tuple)
      continue

  for item in removal:
    print(f'Removing {names}')
    dataset[category].remove(item)
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# =========================================================
# manufacturing is processing
# =========================================================
# =========================================================
# mineral_extraction is processing
# =========================================================
# =========================================================
# power is processing
# =========================================================
# =========================================================
# waste is processing
# =========================================================

# %%
# Add a column on each dataset showing which industry (agriculture, buildings etc.)

columns = ['start_time', 'end_time', 'gas', 'emissions_quantity', 'iso3_country', 'temporal_granularity']
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')

  removal = []
  for data_tuple in dataset[category]:
    names, df = data_tuple
    index = dataset[category].index(data_tuple)
    df = df.withColumn('industry', lit(category))
    new_tuple = (names, df)
    dataset[category][index] = new_tuple
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# =========================================================
# manufacturing is processing
# =========================================================
# =========================================================
# mineral_extraction is processing
# =========================================================
# =========================================================
# power is processing
# =========================================================
# =========================================================
# waste is processing
# =========================================================

# %%
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')
  for data_tuple in dataset[category]:
    names, df = data_tuple
    print(f'Schema for: {names}')
    show_schemas(df)
    print(f'=========================================================')
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# Schema for: country_manure-management_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_cropland-fires_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_cropland-fires_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_rice-cultivation_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_synthetic-fertilizer-application-top500_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_synthetic-fertilizer-application_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_other-agricultural-soil-emissions_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_rice-cultivation-top500_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_enteric-fermentation_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# Schema for: country_residential-and-commercial-onsite-fuel-usage_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_other-onsite-fuel-usage_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# Schema for: country_fluorinated-gases_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# Schema for: country_other-fossil-fuel-operations_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_coal-mining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_solid-fuel-transformation_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_coal-mining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_oil-and-gas-refining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_oil-and-gas-production-and-transport_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_oil-and-gas-production-and-transport_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_oil-and-gas-refining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# =========================================================
# manufacturing is processing
# =========================================================
# Schema for: country_other-manufacturing_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_chemicals_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_pulp-and-paper_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_cement_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_cement_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_aluminum_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_steel_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_steel_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_aluminum_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# =========================================================
# mineral_extraction is processing
# =========================================================
# Schema for: asset_copper-mining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_iron-mining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_bauxite-mining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_bauxite-mining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_sand-quarrying_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_rock-quarrying_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_copper-mining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_iron-mining_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# =========================================================
# power is processing
# =========================================================
# Schema for: country_other-energy-use_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_electricity-generation_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: long (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_electricity-generation_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: integer (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# =========================================================
# waste is processing
# =========================================================
# Schema for: country_incineration-and-open-burning-of-waste_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_biological-treatment-of-solid-waste-and-biogenic_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: asset_solid-waste-disposal_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_solid-waste-disposal_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================
# Schema for: country_wastewater-treatment-and-discharge_emissions.csv
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- end_time: timestamp (nullable = true)
#  |-- gas: string (nullable = true)
#  |-- emissions_quantity: double (nullable = true)
#  |-- iso3_country: string (nullable = true)
#  |-- temporal_granularity: string (nullable = true)
#  |-- industry: string (nullable = false)
#
# =========================================================

# %%
# Print the gasses (Month, Annual, Null or None at all)
"""
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')
  for data_tuple in dataset[category]:
    names, df = data_tuple
    print(f'Gas for: {names}')
    gran = get_uniquness(df, 'gas')
    if gran is None:
      print(f'Error for {name}')
    else:
      gran.show()
    print(f'=========================================================')
    """
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# Gas for: country_enteric-fermentation_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_synthetic-fertilizer-application_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_rice-cultivation-top500_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_other-agricultural-soil-emissions_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_synthetic-fertilizer-application-top500_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_manure-management_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_cropland-fires_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_cropland-fires_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_rice-cultivation_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# Gas for: country_other-onsite-fuel-usage_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_residential-and-commercial-onsite-fuel-usage_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# Gas for: country_fluorinated-gases_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# Gas for: country_oil-and-gas-refining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_coal-mining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_oil-and-gas-production-and-transport_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_oil-and-gas-production-and-transport_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_oil-and-gas-refining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_coal-mining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_other-fossil-fuel-operations_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_solid-fuel-transformation_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# =========================================================
# manufacturing is processing
# =========================================================
# Gas for: asset_cement_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_aluminum_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_aluminum_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_other-manufacturing_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_cement_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_pulp-and-paper_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_steel_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_steel_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_chemicals_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# =========================================================
# mineral_extraction is processing
# =========================================================
# Gas for: asset_copper-mining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_sand-quarrying_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_copper-mining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_bauxite-mining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_bauxite-mining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_iron-mining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_iron-mining_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_rock-quarrying_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# =========================================================
# power is processing
# =========================================================
# Gas for: country_electricity-generation_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_other-energy-use_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: asset_electricity-generation_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# =========================================================
# waste is processing
# =========================================================
# Gas for: asset_solid-waste-disposal_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_incineration-and-open-burning-of-waste_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_biological-treatment-of-solid-waste-and-biogenic_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_wastewater-treatment-and-discharge_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================
# Gas for: country_solid-waste-disposal_emissions.csv
# +----------+
# |       gas|
# +----------+
# | co2e_20yr|
# |co2e_100yr|
# |       ch4|
# |       co2|
# |       n2o|
# +----------+
#
# =========================================================

# %%
# Print the temporal granularities (Month, Annual, Null or None at all)
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')
  for data_tuple in dataset[category]:
    names, df = data_tuple
    print(f'Printing the data for {names}')
    df.show(20)
    print(f'=========================================================')
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# Printing the data for country_manure-management_emissions.csv
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+
# |         start_time|           end_time|       gas|  emissions_quantity|iso3_country|temporal_granularity|   industry|
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         MMR|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         PHL|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         SGP|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         THA|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         TLS|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|            158037.5|         TLS|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         VNM|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|              8269.5|         VNM|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|                 0.0|         BRN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|  30.200000000000003|         BRN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|  360.70000000000005|         BRN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|  38271.600000000006|         BRN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|  18102.600000000002|         BRN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|                 0.0|         IDN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|             19302.9|         IDN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|  171238.40000000002|         IDN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|1.9479991200000003E7|         IDN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|   9909943.700000001|         IDN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|                 0.0|         KHM|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|              2491.1|         KHM|                null|agriculture|
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_cropland-fires_emissions.csv
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+
# |         start_time|           end_time|       gas|  emissions_quantity|iso3_country|temporal_granularity|   industry|
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|  207.34091562239996|         BRN|              annual|agriculture|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|       1.05811888896|         BRN|              annual|agriculture|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|0.012596653439999998|         BRN|              annual|agriculture|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|  240.30131901350393|         BRN|              annual|agriculture|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|  296.69905579507196|         BRN|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|   3091060.840542791|         IDN|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|  15774.551069598738|         IDN|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|  187.79227463807993|         IDN|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|   3582438.106360802|         IDN|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|    4423221.67837041|         IDN|              annual|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|   488426.7644903825|         IDN|              annual|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|  2492.5788710323136|         IDN|              annual|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|  29.673557988480002|         IDN|              annual|agriculture|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|  4084023.2946839402|         KHM|              annual|agriculture|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|   20841.91717821697|         KHM|              annual|agriculture|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|  248.11806164543995|         KHM|              annual|agriculture|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|   4733249.014785404|         KHM|              annual|agriculture|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|   5844123.200384374|         KHM|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|   5739916.620021705|         KHM|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|  29292.405594278396|         KHM|              annual|agriculture|
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for asset_cropland-fires_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|   industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |2015-05-01 00:00:00|2015-05-31 00:00:00|       co2|    474.4327847616|         VNM|               month|agriculture|
# |2015-05-01 00:00:00|2015-05-31 00:00:00|       ch4|2.4211636646400003|         VNM|               month|agriculture|
# |2015-05-01 00:00:00|2015-05-31 00:00:00|       n2o|     0.02882337696|         VNM|               month|agriculture|
# |2015-05-01 00:00:00|2015-05-31 00:00:00|co2e_100yr| 549.8520329151361|         VNM|               month|agriculture|
# |2015-05-01 00:00:00|2015-05-31 00:00:00| co2e_20yr| 678.9000562404482|         VNM|               month|agriculture|
# |2016-02-01 00:00:00|2016-02-29 00:00:00|       co2|161.03818241279996|         VNM|               month|agriculture|
# |2016-02-01 00:00:00|2016-02-29 00:00:00|       ch4|0.8218230451199999|         VNM|               month|agriculture|
# |2016-02-01 00:00:00|2016-02-29 00:00:00|       n2o|     0.00978360768|         VNM|               month|agriculture|
# |2016-02-01 00:00:00|2016-02-29 00:00:00|co2e_100yr|  186.637970268288|         VNM|               month|agriculture|
# |2016-02-01 00:00:00|2016-02-29 00:00:00| co2e_20yr|  230.441138573184|         VNM|               month|agriculture|
# |2016-01-01 00:00:00|2016-01-31 00:00:00|       co2|    145.2067331904|         VNM|               month|agriculture|
# |2016-01-01 00:00:00|2016-01-31 00:00:00|       ch4|0.7410307161599999|         VNM|               month|agriculture|
# |2016-01-01 00:00:00|2016-01-31 00:00:00|       n2o|     0.00882179424|         VNM|               month|agriculture|
# |2016-01-01 00:00:00|2016-01-31 00:00:00|co2e_100yr|  168.289839998784|         VNM|               month|agriculture|
# |2016-01-01 00:00:00|2016-01-31 00:00:00| co2e_20yr|  207.786777170112|         VNM|               month|agriculture|
# |2017-05-01 00:00:00|2017-05-31 00:00:00|       co2|     56.6868020544|         VNM|               month|agriculture|
# |2017-05-01 00:00:00|2017-05-31 00:00:00|       ch4|0.2892886617599999|         VNM|               month|agriculture|
# |2017-05-01 00:00:00|2017-05-31 00:00:00|       n2o|0.0034439126399999|         VNM|               month|agriculture|
# |2017-05-01 00:00:00|2017-05-31 00:00:00|co2e_100yr|   65.698143868224|         VNM|               month|agriculture|
# |2017-05-01 00:00:00|2017-05-31 00:00:00| co2e_20yr|   81.117229540032|         VNM|               month|agriculture|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_rice-cultivation_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|   industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       co2|               0.0|         BRN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       ch4|          164.7492|         BRN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       n2o|               0.0|         BRN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|co2e_100yr|        4481.17824|         BRN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00| co2e_20yr|       13311.73536|         BRN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       co2|               0.0|         BRN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       ch4|          180.6179|         BRN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       n2o|               0.0|         BRN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|        4912.80688|         BRN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|       14593.92632|         BRN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       co2|               0.0|         BRN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       ch4|           164.036|         BRN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       n2o|               0.0|         BRN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|co2e_100yr|         4461.7792|         BRN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00| co2e_20yr|        13254.1088|         BRN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|               0.0|         BRN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       ch4|          139.6089|         BRN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|               0.0|         BRN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|        3797.36208|         BRN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|       11280.39912|         BRN|              annual|agriculture|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for asset_synthetic-fertilizer-application-top500_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|   industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       co2|              null|         IDN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       ch4|              null|         IDN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       n2o|0.0203333992129097|         IDN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|co2e_100yr| 5.551017985124357|         IDN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00| co2e_20yr| 5.551017985124357|         IDN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       co2|              null|         IDN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       ch4|              null|         IDN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       n2o|0.0219402359904437|         IDN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|  5.98968442539114|         IDN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|  5.98968442539114|         IDN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       co2|              null|         IDN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       ch4|              null|         IDN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       n2o|0.0239852263341568|         IDN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|co2e_100yr| 6.547966789224815|         IDN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00| co2e_20yr| 6.547966789224815|         IDN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|              null|         IDN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       ch4|              null|         IDN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|0.0219137419619878|         IDN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr| 5.982451555622674|         IDN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr| 5.982451555622674|         IDN|              annual|agriculture|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_synthetic-fertilizer-application_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|   industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       n2o|              null|         BRN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|co2e_100yr|              null|         BRN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00| co2e_20yr|              null|         BRN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       n2o|              null|         BRN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|              null|         BRN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|              null|         BRN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       n2o|              null|         BRN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|co2e_100yr|              null|         BRN|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00| co2e_20yr|              null|         BRN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|              null|         BRN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|              null|         BRN|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       ch4|               0.0|         BRN|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       ch4|               0.0|         BRN|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|              null|         BRN|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|              null|         BRN|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|              null|         BRN|              annual|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|              null|         BRN|              annual|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|              null|         BRN|              annual|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|              null|         BRN|              annual|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|              null|         BRN|              annual|agriculture|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_other-agricultural-soil-emissions_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|   industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         MMR|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         THA|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|15199.400000000001|         THA|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         THA|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|4012641.6000000006|         THA|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|4027841.0000000005|         THA|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         BRN|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         BRN|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         TLS|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|             390.1|         TLS|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         TLS|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|102986.40000000001|         TLS|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|          103376.5|         TLS|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         VNM|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|           21369.2|         VNM|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         VNM|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|         5641468.8|         VNM|                null|agriculture|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|         5662838.0|         VNM|                null|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|               0.0|         BRN|                null|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|             125.0|         BRN|                null|agriculture|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for asset_rice-cultivation-top500_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|   industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       co2|              null|         KHM|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       ch4|3.6325000000000003|         KHM|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       n2o|              null|         KHM|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|co2e_100yr|101.71000000000001|         KHM|              annual|agriculture|
# |2015-01-01 00:00:00|2015-12-31 00:00:00| co2e_20yr|            305.13|         KHM|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       co2|              null|         KHM|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       ch4|3.6325000000000003|         KHM|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       n2o|              null|         KHM|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|101.71000000000001|         KHM|              annual|agriculture|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|            305.13|         KHM|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       co2|              null|         KHM|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       ch4|3.6325000000000003|         KHM|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       n2o|              null|         KHM|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|co2e_100yr|101.71000000000001|         KHM|              annual|agriculture|
# |2017-01-01 00:00:00|2017-12-31 00:00:00| co2e_20yr|            305.13|         KHM|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|              null|         KHM|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       ch4|3.6325000000000003|         KHM|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|              null|         KHM|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|101.71000000000001|         KHM|              annual|agriculture|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|            305.13|         KHM|              annual|agriculture|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_enteric-fermentation_emissions.csv
# +-------------------+-------------------+---------+------------------+------------+--------------------+-----------+
# |         start_time|           end_time|      gas|emissions_quantity|iso3_country|temporal_granularity|   industry|
# +-------------------+-------------------+---------+------------------+------------+--------------------+-----------+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         BRN|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         BRN|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|210.60000000000002|         BRN|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_20yr|           17690.4|         BRN|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         IDN|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         IDN|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|         1078986.5|         IDN|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         KHM|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         KHM|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|          172418.0|         KHM|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         LAO|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         LAO|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|          173237.9|         LAO|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         MMR|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         MMR|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|1264454.4000000001|         MMR|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         PHL|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         PHL|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         SGP|                null|agriculture|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         SGP|                null|agriculture|
# +-------------------+-------------------+---------+------------------+------------+--------------------+-----------+
# only showing top 20 rows
#
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# Printing the data for country_residential-and-commercial-onsite-fuel-usage_emissions.csv
# +-------------------+-------------------+---+--------------------+------------+--------------------+---------+
# |         start_time|           end_time|gas|  emissions_quantity|iso3_country|temporal_granularity| industry|
# +-------------------+-------------------+---+--------------------+------------+--------------------+---------+
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|         115947.5656|         BRN|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|            0.287265|         BRN|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|         1577.546639|         IDN|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|       2.876226053E7|         IDN|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|            1.251245|         KHM|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|         571543.6553|         KHM|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|            0.395968|         LAO|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|         39615.40121|         LAO|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|         1499.211312|         MMR|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|  5533091.1219999995|         MMR|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|       1.067718412E7|         PHL|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|           100.16552|         PHL|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|   588010.7440000001|         SGP|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|  0.9950140000000001|         SGP|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|         3448.030998|         THA|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|1.5643246649999999E7|         THA|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|            3.584865|         TLS|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|         23165.83148|         TLS|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|         2549.785359|         VNM|                null|buildings|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|1.5751284040000001E7|         VNM|                null|buildings|
# +-------------------+-------------------+---+--------------------+------------+--------------------+---------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_other-onsite-fuel-usage_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+---------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity| industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+---------+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         PHL|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         PHL|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         PHL|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         PHL|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         PHL|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         THA|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         THA|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         THA|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         THA|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         THA|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         VNM|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         VNM|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         VNM|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         VNM|                null|buildings|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         VNM|                null|buildings|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         PHL|                null|buildings|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|               0.0|         PHL|                null|buildings|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         PHL|                null|buildings|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|               0.0|         PHL|                null|buildings|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|               0.0|         PHL|                null|buildings|
# +-------------------+-------------------+----------+------------------+------------+--------------------+---------+
# only showing top 20 rows
#
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# Printing the data for country_fluorinated-gases_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|         industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------------+
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         THA|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|               0.0|         THA|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         THA|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         TLS|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|               0.0|         TLS|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         TLS|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|               0.0|         TLS|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|               0.0|         TLS|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         VNM|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|               0.0|         VNM|                null|fluorinated_gases|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         VNM|                null|fluorinated_gases|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|               0.0|         BRN|                null|fluorinated_gases|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|               0.0|         BRN|                null|fluorinated_gases|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       ch4|               0.0|         BRN|                null|fluorinated_gases|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|419914.44008800003|         BRN|                null|fluorinated_gases|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|     177176.726544|         BRN|                null|fluorinated_gases|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         MMR|                null|fluorinated_gases|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         MMR|                null|fluorinated_gases|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         MMR|                null|fluorinated_gases|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         PHL|                null|fluorinated_gases|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------------+
# only showing top 20 rows
#
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# Printing the data for country_other-fossil-fuel-operations_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|            industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         THA|                null|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         TLS|                null|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         VNM|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         SGP|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         THA|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         TLS|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         VNM|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         KHM|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         KHM|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         KHM|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         KHM|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         KHM|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         LAO|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         LAO|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         LAO|                null|fossil_fuel_opera...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|               0.0|         BRN|                null|fossil_fuel_opera...|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       co2|               0.0|         IDN|                null|fossil_fuel_opera...|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       co2|               0.0|         KHM|                null|fossil_fuel_opera...|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       n2o|               0.0|         KHM|                null|fossil_fuel_opera...|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       ch4|               0.0|         KHM|                null|fossil_fuel_opera...|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_coal-mining_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|            industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2015-01-01 00:00:00|2015-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2017-01-01 00:00:00|2017-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_solid-fuel-transformation_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|            industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         THA|                null|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         TLS|                null|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|               0.0|         TLS|                null|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         TLS|                null|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|               0.0|         TLS|                null|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|               0.0|         TLS|                null|fossil_fuel_opera...|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         VNM|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         PHL|                null|fossil_fuel_opera...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|               0.0|         BRN|                null|fossil_fuel_opera...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|               0.0|         BRN|                null|fossil_fuel_opera...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       ch4|               0.0|         BRN|                null|fossil_fuel_opera...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|               0.0|         BRN|                null|fossil_fuel_opera...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|               0.0|         BRN|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         SGP|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         SGP|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         SGP|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         SGP|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         SGP|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         TLS|                null|fossil_fuel_opera...|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         TLS|                null|fossil_fuel_opera...|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for asset_coal-mining_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|            industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|               0.0|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|          209995.0|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|               0.0|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|        6257843.55|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|     1.732456688E7|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|               0.0|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|           28622.0|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|               0.0|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|         852947.52|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|         2361348.0|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|               0.0|         IDN|              annual|fossil_fuel_opera...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|           46290.0|         IDN|              annual|fossil_fuel_opera...|
# ...
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|          23374000|         IDN|              annual|   power|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|                 0|         IDN|              annual|   power|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|          23438000|         IDN|              annual|   power|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|                 0|         IDN|              annual|   power|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|          23438000|         IDN|              annual|   power|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|           4017000|         THA|              annual|   power|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|           5490000|         THA|              annual|   power|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|              null|         THA|              annual|   power|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|              null|         THA|              annual|   power|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|           5490000|         THA|              annual|   power|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# only showing top 20 rows
#
# =========================================================
# =========================================================
# waste is processing
# =========================================================
# Printing the data for country_incineration-and-open-burning-of-waste_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|       156678.7481|         IDN|                null|   waste|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|         289.57115|         IDN|                null|   waste|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       ch4|       32485.85127|         IDN|                null|   waste|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|2961937.0383800003|         IDN|                null|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       co2|        1650.89802|         BRN|                null|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       n2o|          1.139019|         BRN|                null|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       ch4|211.10225799999998|         BRN|                null|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|19684.188707999998|         BRN|                null|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|7863.6012789999995|         BRN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|        1785.03487|         BRN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|          1.231565|         BRN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|        222.796387|         BRN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|20825.064538000002|         BRN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr| 8349.698430999999|         BRN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|       167228.4882|         IDN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|         309.06901|         IDN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|       33867.11318|         IDN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|3093660.2139600003|         IDN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|1197410.9448900002|         IDN|                null|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|       12290.61695|         KHM|                null|   waste|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_biological-treatment-of-solid-waste-and-biogenic_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         BRN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         BRN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         BRN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         BRN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         BRN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         IDN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         IDN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         IDN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         IDN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         IDN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         KHM|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         KHM|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         KHM|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         KHM|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         KHM|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         LAO|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         LAO|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         LAO|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         LAO|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         LAO|                null|   waste|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for asset_solid-waste-disposal_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|              null|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|       343.5918725|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|              null|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|        9620.57243|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|       28861.71729|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|              null|         KHM|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|       2720.050914|         KHM|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|              null|         KHM|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|       76161.42559|         KHM|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|       228484.2768|         KHM|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|              null|         THA|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|       438.8308004|         THA|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|              null|         THA|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|       12287.26241|         THA|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|       36861.78724|         THA|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|              null|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|       215.3121537|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|              null|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|       6028.740302|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|       18086.22091|         MMR|              annual|   waste|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_solid-waste-disposal_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|industry|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       ch4|            3358.0|         BRN|              annual|   waste|
# |2015-01-01 00:00:00|2015-12-31 00:00:00| co2e_20yr|          282072.0|         BRN|              annual|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|          723212.0|         KHM|              annual|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|         2169636.0|         KHM|              annual|   waste|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|co2e_100yr|          723212.0|         KHM|              annual|   waste|
# |2017-01-01 00:00:00|2017-12-31 00:00:00| co2e_20yr|         2169636.0|         KHM|              annual|   waste|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       ch4|           25829.0|         KHM|              annual|   waste|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|          723212.0|         KHM|              annual|   waste|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|         2169636.0|         KHM|              annual|   waste|
# |2017-01-01 00:00:00|2017-12-31 00:00:00| co2e_20yr|         1503600.0|         LAO|              annual|   waste|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|         1503600.0|         LAO|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|           44100.0|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|         1234800.0|         MMR|              annual|   waste|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|         3704400.0|         MMR|              annual|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       ch4|           22800.0|         SGP|              annual|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|          638400.0|         SGP|              annual|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|         1915200.0|         SGP|              annual|   waste|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|          3.3516E7|         THA|              annual|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         BRN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         BRN|                null|   waste|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_wastewater-treatment-and-discharge_emissions.csv
# +-------------------+-------------------+---+------------------+------------+--------------------+--------+
# |         start_time|           end_time|gas|emissions_quantity|iso3_country|temporal_granularity|industry|
# +-------------------+-------------------+---+------------------+------------+--------------------+--------+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         BRN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|n2o|               0.0|         BRN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         IDN|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         KHM|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         LAO|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         MMR|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         PHL|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         SGP|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         THA|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         TLS|                null|   waste|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         VNM|                null|   waste|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         BRN|                null|   waste|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|n2o|               0.0|         BRN|                null|   waste|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         IDN|                null|   waste|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         KHM|                null|   waste|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         LAO|                null|   waste|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         MMR|                null|   waste|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         PHL|                null|   waste|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         SGP|                null|   waste|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         THA|                null|   waste|
# +-------------------+-------------------+---+------------------+------------+--------------------+--------+
# only showing top 20 rows
#
# =========================================================

# %%
# Replace the nulls, co2e things
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')
  for data_tuple in dataset[category]:
    names, df = data_tuple
    index = dataset[category].index(data_tuple)
    df = df.na.fill(value = 0, subset = ['emissions_quantity'])
    df = df.na.fill(value = 'annual', subset = ['temporal_granularity'])
    #df = df.withColumn('gas', regexp_replace('gas', 'co2e_100yr', 'co2'))
    #df = df.withColumn('gas', regexp_replace('gas', 'co2e_20yr', 'co2'))
    dataset[category][index] = (names, df)
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# =========================================================
# manufacturing is processing
# =========================================================
# =========================================================
# mineral_extraction is processing
# =========================================================
# =========================================================
# power is processing
# =========================================================
# =========================================================
# waste is processing
# =========================================================

# %%
# Create Rate Column
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')
  for data_tuple in dataset[category]:
    names, df = data_tuple
    index = dataset[category].index(data_tuple)

    df = df.withColumn('rate',
                       when(df.temporal_granularity == 'month', df.emissions_quantity / (datediff(df.end_time, df.start_time))).
                       when(df.temporal_granularity == 'annual', df.emissions_quantity / 365))

    new_tuple = (names, df)
    dataset[category][index] = new_tuple
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# =========================================================
# manufacturing is processing
# =========================================================
# =========================================================
# mineral_extraction is processing
# =========================================================
# =========================================================
# power is processing
# =========================================================
# =========================================================
# waste is processing
# =========================================================

# %%
for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')
  for data_tuple in dataset[category]:
    names, df = data_tuple
    print(f'Printing the data for {names}')
    df.show(20)
    print(f'=========================================================')
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# Printing the data for country_manure-management_emissions.csv
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+-------------------+
# |         start_time|           end_time|       gas|  emissions_quantity|iso3_country|temporal_granularity|   industry|               rate|
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+-------------------+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         MMR|              annual|agriculture|                0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         PHL|              annual|agriculture|                0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         SGP|              annual|agriculture|                0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         THA|              annual|agriculture|                0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         TLS|              annual|agriculture|                0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|            158037.5|         TLS|              annual|agriculture| 432.97945205479454|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|                 0.0|         VNM|              annual|agriculture|                0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|              8269.5|         VNM|              annual|agriculture| 22.656164383561645|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|                 0.0|         BRN|              annual|agriculture|                0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|  30.200000000000003|         BRN|              annual|agriculture|0.08273972602739726|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|  360.70000000000005|         BRN|              annual|agriculture|  0.988219178082192|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|  38271.600000000006|         BRN|              annual|agriculture|   104.853698630137|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|  18102.600000000002|         BRN|              annual|agriculture|  49.59616438356165|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|                 0.0|         IDN|              annual|agriculture|                0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|             19302.9|         IDN|              annual|agriculture|  52.88465753424658|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|  171238.40000000002|         IDN|              annual|agriculture| 469.14630136986307|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|1.9479991200000003E7|         IDN|              annual|agriculture| 53369.838904109594|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|   9909943.700000001|         IDN|              annual|agriculture|  27150.53068493151|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|                 0.0|         KHM|              annual|agriculture|                0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|              2491.1|         KHM|              annual|agriculture|  6.824931506849315|
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+-------------------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_cropland-fires_emissions.csv
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+--------------------+
# |         start_time|           end_time|       gas|  emissions_quantity|iso3_country|temporal_granularity|   industry|                rate|
# +-------------------+-------------------+----------+--------------------+------------+--------------------+-----------+--------------------+
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|  207.34091562239996|         BRN|              annual|agriculture|  0.5680573030750684|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|       1.05811888896|         BRN|              annual|agriculture|0.002898955860164...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|0.012596653439999998|         BRN|              annual|agriculture|3.451137928767122...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|  240.30131901350393|         BRN|              annual|agriculture|  0.6583597781191889|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|  296.69905579507196|         BRN|              annual|agriculture|  0.8128741254659506|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|   3091060.840542791|         IDN|              annual|agriculture|   8468.659837103536|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|  15774.551069598738|         IDN|              annual|agriculture|   43.21794813588695|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|  187.79227463807993|         IDN|              annual|agriculture|   0.514499382570082|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr

# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|               0.0|         KHM|              annual|agriculture|                 0.0|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|101.71000000000001|         KHM|              annual|agriculture| 0.27865753424657536|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|            305.13|         KHM|              annual|agriculture|  0.8359726027397261|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------+--------------------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_enteric-fermentation_emissions.csv
# +-------------------+-------------------+---------+------------------+------------+--------------------+-----------+------------------+
# |         start_time|           end_time|      gas|emissions_quantity|iso3_country|temporal_granularity|   industry|              rate|
# +-------------------+-------------------+---------+------------------+------------+--------------------+-----------+------------------+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         BRN|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         BRN|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|210.60000000000002|         BRN|              annual|agriculture|0.5769863013698631|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_20yr|           17690.4|         BRN|              annual|agriculture|48.466849315068494|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         IDN|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         IDN|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|         1078986.5|         IDN|              annual|agriculture| 2956.127397260274|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         KHM|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         KHM|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|          172418.0|         KHM|              annual|agriculture|472.37808219178083|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         LAO|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         LAO|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|          173237.9|         LAO|              annual|agriculture| 474.6243835616438|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         MMR|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         MMR|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      ch4|1264454.4000000001|         MMR|              annual|agriculture|3464.2586301369865|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         PHL|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         PHL|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      co2|               0.0|         SGP|              annual|agriculture|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|      n2o|               0.0|         SGP|              annual|agriculture|               0.0|
# +-------------------+-------------------+---------+------------------+------------+--------------------+-----------+------------------+
# only showing top 20 rows
#
# =========================================================
# =========================================================
# buildings is processing
# =========================================================
# Printing the data for country_residential-and-commercial-onsite-fuel-usage_emissions.csv
# +-------------------+-------------------+---+--------------------+------------+--------------------+---------+--------------------+
# |         start_time|           end_time|gas|  emissions_quantity|iso3_country|temporal_granularity| industry|                rate|
# +-------------------+-------------------+---+--------------------+------------+--------------------+---------+--------------------+
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|         115947.5656|         BRN|              annual|buildings|   317.6645632876712|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|            0.287265|         BRN|              annual|buildings| 7.87027397260274E-4|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|         1577.546639|         IDN|              annual|buildings|   4.322045586301369|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|       2.876226053E7|         IDN|              annual|buildings|   78800.71378082193|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|            1.251245|         KHM|              annual|buildings|0.003428068493150...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|         571543.6553|         KHM|              annual|buildings|   1565.873028219178|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|            0.395968|         LAO|              annual|buildings|0.001084843835616...|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|         39615.40121|         LAO|              annual|buildings|  108.53534578082193|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|         1499.211312|         MMR|              annual|buildings|  4.1074282520547944|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|  5533091.1219999995|         MMR|              annual|buildings|  15159.153758904109|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|       1.067718412E7|         PHL|              annual|buildings|   29252.55923287671|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|           100.16552|         PHL|              annual|buildings| 0.27442608219178083|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|   588010.7440000001|         SGP|              annual|buildings|  1610.9883397260276|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|  0.9950140000000001|         SGP|              annual|buildings|0.002726065753424658|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|         3448.030998|         THA|              annual|buildings|    9.44666026849315|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|1.5643246649999999E7|         THA|              annual|buildings|            42858.21|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|            3.584865|         TLS|              annual|buildings| 0.00982154794520548|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|         23165.83148|         TLS|              annual|buildings|  63.468031452054795|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|n2o|         2549.785359|         VNM|              annual|buildings|   6.985713312328767|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2|1.5751284040000001E7|         VNM|              annual|buildings|   43154.20284931507|
# +-------------------+-------------------+---+--------------------+------------+--------------------+---------+--------------------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_other-onsite-fuel-usage_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+---------+----+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity| industry|rate|
# +-------------------+-------------------+----------+------------------+------------+--------------------+---------+----+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         PHL|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         PHL|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         PHL|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         PHL|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         PHL|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         THA|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         THA|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         THA|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         THA|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         THA|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         VNM|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         VNM|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         VNM|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         VNM|              annual|buildings| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         VNM|              annual|buildings| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         PHL|              annual|buildings| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|               0.0|         PHL|              annual|buildings| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         PHL|              annual|buildings| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|               0.0|         PHL|              annual|buildings| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|               0.0|         PHL|              annual|buildings| 0.0|
# +-------------------+-------------------+----------+------------------+------------+--------------------+---------+----+
# only showing top 20 rows
#
# =========================================================
# =========================================================
# fluorinated_gases is processing
# =========================================================
# Printing the data for country_fluorinated-gases_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------------+------------------+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|         industry|              rate|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------------+------------------+
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         THA|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|               0.0|         THA|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         THA|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         TLS|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|               0.0|         TLS|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         TLS|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|               0.0|         TLS|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|               0.0|         TLS|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         VNM|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       n2o|               0.0|         VNM|              annual|fluorinated_gases|               0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       ch4|               0.0|         VNM|              annual|fluorinated_gases|               0.0|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fluorinated_gases|               0.0|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|               0.0|         BRN|              annual|fluorinated_gases|               0.0|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       ch4|               0.0|         BRN|              annual|fluorinated_gases|               0.0|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|419914.44008800003|         BRN|              annual|fluorinated_gases| 1150.450520789041|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|     177176.726544|         BRN|              annual|fluorinated_gases|485.41568916164385|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         MMR|              annual|fluorinated_gases|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         MMR|              annual|fluorinated_gases|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         MMR|              annual|fluorinated_gases|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         PHL|              annual|fluorinated_gases|               0.0|
# +-------------------+-------------------+----------+------------------+------------+--------------------+-----------------+------------------+
# only showing top 20 rows
#
# =========================================================
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# Printing the data for country_other-fossil-fuel-operations_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+----+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|            industry|rate|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+----+
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         THA|              annual|fossil_fuel_opera...| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         TLS|              annual|fossil_fuel_opera...| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         VNM|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         SGP|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         THA|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         TLS|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         VNM|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         KHM|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         KHM|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         KHM|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         KHM|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         KHM|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         LAO|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         LAO|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         LAO|              annual|fossil_fuel_opera...| 0.0|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       co2|               0.0|         IDN|              annual|fossil_fuel_opera...| 0.0|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       co2|               0.0|         KHM|              annual|fossil_fuel_opera...| 0.0|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       n2o|               0.0|         KHM|              annual|fossil_fuel_opera...| 0.0|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       ch4|               0.0|         KHM|              annual|fossil_fuel_opera...| 0.0|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+----+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_coal-mining_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+----+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|            industry|rate|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------------------+----+
# |2015-01-01 00:00:00|2015-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2015-01-01 00:00:00|2015-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2015-01-01 00:00:00|2015-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2017-01-01 00:00:00|2017-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2017-01-01 00:00:00|2017-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|fossil_fuel_opera...| 0.0|
# ...
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|industry|                rate|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+--------------------+
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       co2|       156678.7481|         IDN|              annual|   waste|  429.25684410958905|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       n2o|         289.57115|         IDN|              annual|   waste|  0.7933456164383561|
# |2018-01-01 00:00:00|2018-12-31 00:00:00|       ch4|       32485.85127|         IDN|              annual|   waste|   89.00233224657534|
# |2018-01-01 00:00:00|2018-12-31 00:00:00| co2e_20yr|2961937.0383800003|         IDN|              annual|   waste|   8114.895995561645|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       co2|        1650.89802|         BRN|              annual|   waste|   4.523008273972603|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       n2o|          1.139019|         BRN|              annual|   waste|           0.0031206|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|       ch4|211.10225799999998|         BRN|              annual|   waste|  0.5783623506849315|
# |2016-01-01 00:00:00|2016-12-31 00:00:00| co2e_20yr|19684.188707999998|         BRN|              annual|   waste|   53.92928413150684|
# |2016-01-01 00:00:00|2016-12-31 00:00:00|co2e_100yr|7863.6012789999995|         BRN|              annual|   waste|  21.544113093150685|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|        1785.03487|         BRN|              annual|   waste|   4.890506493150685|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|          1.231565|         BRN|              annual|   waste|0.003374150684931...|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|        222.796387|         BRN|              annual|   waste|  0.6104010602739727|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|20825.064538000002|         BRN|              annual|   waste|  57.054971336986306|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr| 8349.698430999999|         BRN|              annual|   waste|  22.875886112328764|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|       167228.4882|         IDN|              annual|   waste|   458.1602416438356|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       n2o|         309.06901|         IDN|              annual|   waste|  0.8467644109589041|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       ch4|       33867.11318|         IDN|              annual|   waste|    92.7866114520548|
# |2021-01-01 00:00:00|2021-12-31 00:00:00| co2e_20yr|3093660.2139600003|         IDN|              annual|   waste|    8475.78140810959|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|co2e_100yr|1197410.9448900002|         IDN|              annual|   waste|  3280.5779312054797|
# |2021-01-01 00:00:00|2021-12-31 00:00:00|       co2|       12290.61695|         KHM|              annual|   waste|   33.67292315068493|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+--------------------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_biological-treatment-of-solid-waste-and-biogenic_emissions.csv
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+----+
# |         start_time|           end_time|       gas|emissions_quantity|iso3_country|temporal_granularity|industry|rate|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+----+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         BRN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         BRN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         BRN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         BRN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|         BRN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         IDN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         IDN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       ch4|               0.0|         IDN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00| co2e_20yr|               0.0|         IDN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2e_100yr|               0.0|

# |2020-01-01 00:00:00|2020-12-31 00:00:00|       co2|               0.0|         BRN|              annual|   waste|               0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|       n2o|               0.0|         BRN|              annual|   waste|               0.0|
# +-------------------+-------------------+----------+------------------+------------+--------------------+--------+------------------+
# only showing top 20 rows
#
# =========================================================
# Printing the data for country_wastewater-treatment-and-discharge_emissions.csv
# +-------------------+-------------------+---+------------------+------------+--------------------+--------+----+
# |         start_time|           end_time|gas|emissions_quantity|iso3_country|temporal_granularity|industry|rate|
# +-------------------+-------------------+---+------------------+------------+--------------------+--------+----+
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         BRN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|n2o|               0.0|         BRN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         IDN|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         KHM|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         LAO|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         MMR|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         PHL|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         SGP|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         THA|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         TLS|              annual|   waste| 0.0|
# |2020-01-01 00:00:00|2020-12-31 00:00:00|co2|               0.0|         VNM|              annual|   waste| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         BRN|              annual|   waste| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|n2o|               0.0|         BRN|              annual|   waste| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         IDN|              annual|   waste| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         KHM|              annual|   waste| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         LAO|              annual|   waste| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         MMR|              annual|   waste| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         PHL|              annual|   waste| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         SGP|              annual|   waste| 0.0|
# |2019-01-01 00:00:00|2019-12-31 00:00:00|co2|               0.0|         THA|              annual|   waste| 0.0|
# +-------------------+-------------------+---+------------------+------------+--------------------+--------+----+
# only showing top 20 rows
#
# =========================================================

# %%
# Append all data into one dataframe

d_name, dataframe = dataset['agriculture'][0]

for category in dataset:
  print(f'=========================================================')
  print(f'{category} is processing')
  print(f'=========================================================')
  for data_tuple in dataset[category]:
    name, df = data_tuple
    if name == d_name:
      continue
    else:
      print(f'Appending the data for {name}')
      dataframe = dataframe.union(df)

#print((dataframe.count(), len(dataframe.columns)))
# Out:
# =========================================================
# agriculture is processing
# =========================================================
# Appending the data for country_cropland-fires_emissions.csv
# Appending the data for asset_cropland-fires_emissions.csv
# Appending the data for country_rice-cultivation_emissions.csv
# Appending the data for asset_synthetic-fertilizer-application-top500_emissions.csv
# Appending the data for country_synthetic-fertilizer-application_emissions.csv
# Appending the data for country_other-agricultural-soil-emissions_emissions.csv
# Appending the data for asset_rice-cultivation-top500_emissions.csv
# Appending the data for country_enteric-fermentation_emissions.csv
# =========================================================
# buildings is processing
# =========================================================
# Appending the data for country_residential-and-commercial-onsite-fuel-usage_emissions.csv
# Appending the data for country_other-onsite-fuel-usage_emissions.csv
# =========================================================
# fluorinated_gases is processing
# =========================================================
# Appending the data for country_fluorinated-gases_emissions.csv
# =========================================================
# fossil_fuel_operations is processing
# =========================================================
# Appending the data for country_other-fossil-fuel-operations_emissions.csv
# Appending the data for country_coal-mining_emissions.csv
# Appending the data for country_solid-fuel-transformation_emissions.csv
# Appending the data for asset_coal-mining_emissions.csv
# Appending the data for country_oil-and-gas-refining_emissions.csv
# Appending the data for country_oil-and-gas-production-and-transport_emissions.csv
# Appending the data for asset_oil-and-gas-production-and-transport_emissions.csv
# Appending the data for asset_oil-and-gas-refining_emissions.csv
# =========================================================
# manufacturing is processing
# =========================================================
# Appending the data for country_other-manufacturing_emissions.csv
# Appending the data for country_chemicals_emissions.csv
# Appending the data for country_pulp-and-paper_emissions.csv
# Appending the data for asset_cement_emissions.csv
# Appending the data for country_cement_emissions.csv
# Appending the data for country_aluminum_emissions.csv
# Appending the data for asset_steel_emissions.csv
# Appending the data for country_steel_emissions.csv
# Appending the data for asset_aluminum_emissions.csv
# =========================================================
# mineral_extraction is processing
# =========================================================
# Appending the data for asset_copper-mining_emissions.csv
# Appending the data for country_iron-mining_emissions.csv
# Appending the data for asset_bauxite-mining_emissions.csv
# Appending the data for country_bauxite-mining_emissions.csv
# Appending the data for country_sand-quarrying_emissions.csv
# Appending the data for country_rock-quarrying_emissions.csv
# Appending the data for country_copper-mining_emissions.csv
# Appending the data for asset_iron-mining_emissions.csv
# =========================================================
# power is processing
# =========================================================
# Appending the data for country_other-energy-use_emissions.csv
# Appending the data for country_electricity-generation_emissions.csv
# Appending the data for asset_electricity-generation_emissions.csv
# =========================================================
# waste is processing
# =========================================================
# Appending the data for country_incineration-and-open-burning-of-waste_emissions.csv
# Appending the data for country_biological-treatment-of-solid-waste-and-biogenic_emissions.csv
# Appending the data for asset_solid-waste-disposal_emissions.csv
# Appending the data for country_solid-waste-disposal_emissions.csv
# Appending the data for country_wastewater-treatment-and-discharge_emissions.csv

# %%
# Find the descriptions of the rate and the emissions quantity
# Note: This is for Indonesia only since this is the focus of the project.

description = dataframe.filter(col('iso3_country').isin(['IDN']))
co2 = description.filter(col('gas').isin(['co2'])).describe(['emissions_quantity', 'rate'])
co2e_100yr = description.filter(col('gas').isin(['co2e_100yr'])).describe(['emissions_quantity', 'rate'])
co2e_20yr = description.filter(col('gas').isin(['co2e_20yr'])).describe(['emissions_quantity', 'rate'])
n2o = description.filter(col('gas').isin(['n2o'])).describe(['emissions_quantity', 'rate'])
ch4 = description.filter(col('gas').isin(['ch4'])).describe(['emissions_quantity', 'rate'])

gas_list = [('co2', co2), ('co2e_100yr', co2e_100yr),
            ('co2e_20yr', co2e_20yr), ('n2o', n2o), ('ch4', ch4)]

for gas_data in gas_list:
  name, gas = gas_data
  print(f'=============================={name}==============================')
  gas.show()
  print(f'=================================================================')

# %%
# Create csv files from Pyspark
dataframe.write.options(header='True', delimiter=',').csv('environment.csv')

# %%
import os
import pandas as pd

final_dataframe = []

for item in os.listdir('environment.csv'):
  try:
    print(item)
    p = pd.DataFrame(pd.read_csv(f'environment.csv/{item}'))
    print(item)
    final_dataframe.append(p)
  except:
    continue

#final_dataframe.to_csv('environment_processed.csv')
# Out:
# .part-00288-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00370-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00399-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00399-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00347-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00246-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00246-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00328-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00328-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00441-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00125-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00125-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00413-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00413-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00335-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00009-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00009-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00540-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00540-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00562-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00028-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00318-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00318-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00179-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00180-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00583-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00583-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00167-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00167-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00216-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00437-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00333-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00272-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00403-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00403-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00415-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00497-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00557-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00557-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00260-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00260-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00203-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00203-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00247-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00368-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00229-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00477-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00477-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00592-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00145-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00145-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00138-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00138-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00511-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00511-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00029-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00571-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00033-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00070-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00070-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00082-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00222-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00218-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00519-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00519-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00484-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00484-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00302-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00116-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00321-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00021-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00535-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00278-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00209-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00455-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00455-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00040-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00038-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00038-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00616-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-00236-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00236-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00555-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00555-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00181-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00181-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00325-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00325-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00277-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# part-00277-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv
# .part-00456-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# .part-00416-8badf1e4-6569-4213-9378-5d6aab1a3b88-c000.csv.crc
# part-